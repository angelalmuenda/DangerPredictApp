# %%
# %matplotlib notebook
import pandas

crime_places = pandas.read_csv('generated/crime_places_presence.csv', encoding='utf-8')
crime_places.drop(['Unnamed: 0'], axis=1, inplace=True)
crime_places.head()
# Out:
#        lng      lat        date          customdate      time  \
# 0  125.808  7.44808  30/07/2017  Sun - Jul 30, 2017  16:11:00
# 1  125.803  7.44675  30/07/2017  Sun - Jul 30, 2017   0:20:00
# 2  125.803  7.44897  30/07/2017  Sun - Jul 30, 2017   0:20:00
# 3  125.818  7.45982  30/07/2017  Sun - Jul 30, 2017  20:50:00
# 4  125.818  7.46016  30/07/2017  Sun - Jul 30, 2017  20:50:00
#
#                         crime           barangay        city  \
# 0  Vehicular Traffic Accident  Magugpo Poblacion  Tagum City
# 1                      MURDER  Magugpo Poblacion  Tagum City
# 2           PHYSICAL INJURIES  Magugpo Poblacion  Tagum City
# 3                      MURDER      Magugpo North  Tagum City
# 4           PHYSICAL INJURIES      Magugpo North  Tagum City
#
#               modus   Bank         ...          Reservior  \
# 0     Not Indicated  160.0         ...                NaN
# 1  Stabbing/Hacking  120.0         ...                NaN
# ...

# %%
import matplotlib as mpl
# Out:
# 'nbAgg'
